# %%
import pandas as pd
df = pd.read_csv('realtor_data.csv')
df
# Out:
#           status  bed  bath  acre_lot           city        state  zip_code  \
# 0       for_sale  3.0   2.0      0.12       Adjuntas  Puerto Rico     601.0
# 1       for_sale  4.0   2.0      0.08       Adjuntas  Puerto Rico     601.0
# 2       for_sale  2.0   1.0      0.15     Juana Diaz  Puerto Rico     795.0
# 3       for_sale  4.0   2.0      0.10          Ponce  Puerto Rico     731.0
# 4       for_sale  6.0   2.0      0.05       Mayaguez  Puerto Rico     680.0
# ...          ...  ...   ...       ...            ...          ...       ...
# 904961  for_sale  2.0   2.0       NaN  New York City     New York   10463.0
# 904962  for_sale  2.0   2.0       NaN          Bronx     New York   10463.0
# 904963  for_sale  NaN   1.0       NaN          Bronx     New York   10463.0
# 904964  for_sale  3.0   2.0       NaN          Bronx     New York   10463.0
# 904965  for_sale  3.0   3.0       NaN  New York City     New York   10463.0
#
#         house_size prev_sold_date     price
# ...

# %%
df2 = df[df.state=='New York']
df3 = df[df.state=='Massachusetts']
df4 = df[df.state=='New Jersey']
df5 = pd.concat([df2, df3, df4], ignore_index=True)
df5
# Out:
#           status  bed  bath  acre_lot       city       state  zip_code  \
# 0       for_sale  3.0   1.0     60.00     Berlin    New York   12022.0
# 1       for_sale  3.0   2.0      2.02  Claverack    New York   12521.0
# 2       for_sale  4.0   2.0      0.24     Copake    New York   12521.0
# 3       for_sale  3.0   3.0      1.90     Copake    New York   12516.0
# 4       for_sale  3.0   2.0      2.00     Copake    New York   12517.0
# ...          ...  ...   ...       ...        ...         ...       ...
# 604416  for_sale  4.0   2.0      0.19    Emerson  New Jersey    7630.0
# 604417  for_sale  5.0   4.0      0.45    Closter  New Jersey    7624.0
# 604418  for_sale  4.0   5.0      0.25  Englewood  New Jersey    7631.0
# 604419  for_sale  4.0   2.0      0.40    Closter  New Jersey    7624.0
# 604420  for_sale  3.0   3.0       NaN  Englewood  New Jersey    7631.0
#
#         house_size prev_sold_date      price
# 0           1176.0            NaN   175000.0
# ...

# %%
df6 = df5[df5.bed<=6]
df7 = df6[df6.bath<=6]
df8 = df7[df7.house_size<=5200]
df9 = df8[df7.house_size>=1782]
df10 = df9[df9.price<=1995000]
df11 = df10[df10.price>=174500]
df11
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15920\2431766221.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df9 = df8[df7.house_size>=1782]
#           status  bed  bath  acre_lot            city       state  zip_code  \
# 3       for_sale  3.0   3.0      1.90          Copake    New York   12516.0
# 13      for_sale  4.0   3.0      1.29          Nassau    New York   12123.0
# 16      for_sale  3.0   2.0      5.01    East Chatham    New York   12060.0
# 17      for_sale  4.0   3.0      2.15         Valatie    New York   12184.0
# 19      for_sale  4.0   4.0     12.80      Kinderhook    New York   12106.0
# ...          ...  ...   ...       ...             ...         ...       ...
# 604332  for_sale  5.0   4.0       NaN  East Brunswick  New Jersey    8816.0
# 604342  for_sale  5.0   3.0      0.08         Roselle  New Jersey    7203.0
# 604348  for_sale  2.0   3.0      0.10        Metuchen  New Jersey    8840.0
# ...

# %%
df12 = df11.drop(['status', 'acre_lot', 'zip_code', 'prev_sold_date'], axis='columns')
df12
# Out:
#         bed  bath            city       state  house_size     price
# 3       3.0   3.0          Copake    New York      1800.0  419000.0
# 13      4.0   3.0          Nassau    New York      2274.0  194900.0
# 16      3.0   2.0    East Chatham    New York      2504.0  435000.0
# 17      4.0   3.0         Valatie    New York      2248.0  429900.0
# 19      4.0   4.0      Kinderhook    New York      1980.0  649000.0
# ...     ...   ...             ...         ...         ...       ...
# 604332  5.0   4.0  East Brunswick  New Jersey      3337.0  925000.0
# 604342  5.0   3.0         Roselle  New Jersey      1998.0  379900.0
# 604348  2.0   3.0        Metuchen  New Jersey      3300.0  718000.0
# 604391  3.0   2.0     Jersey City  New Jersey      1828.0  895000.0
# 604395  3.0   4.0       Cliffwood  New Jersey      1917.0  569990.0
#
# [105416 rows x 6 columns]

# %%
df12.isnull().sum()
# Out:
# bed           0
# bath          0
# city          5
# state         0
# house_size    0
# price         0
# dtype: int64

# %%
df12.dropna()
# Out:
#         bed  bath            city       state  house_size     price
# 3       3.0   3.0          Copake    New York      1800.0  419000.0
# 13      4.0   3.0          Nassau    New York      2274.0  194900.0
# 16      3.0   2.0    East Chatham    New York      2504.0  435000.0
# 17      4.0   3.0         Valatie    New York      2248.0  429900.0
# 19      4.0   4.0      Kinderhook    New York      1980.0  649000.0
# ...     ...   ...             ...         ...         ...       ...
# 604332  5.0   4.0  East Brunswick  New Jersey      3337.0  925000.0
# 604342  5.0   3.0         Roselle  New Jersey      1998.0  379900.0
# 604348  2.0   3.0        Metuchen  New Jersey      3300.0  718000.0
# 604391  3.0   2.0     Jersey City  New Jersey      1828.0  895000.0
# 604395  3.0   4.0       Cliffwood  New Jersey      1917.0  569990.0
#
# [105411 rows x 6 columns]

# %%
df12[df12['city']=='East Chatham']
# Out:
#       bed  bath          city     state  house_size      price
# 16    3.0   2.0  East Chatham  New York      2504.0   435000.0
# 424   4.0   3.0  East Chatham  New York      2508.0  1225000.0
# 608   3.0   3.0  East Chatham  New York      1800.0   499000.0
# 652   4.0   3.0  East Chatham  New York      2891.0   649900.0
# 818   3.0   2.0  East Chatham  New York      2504.0   435000.0
# 822   4.0   3.0  East Chatham  New York      2891.0   649900.0
# 828   3.0   2.0  East Chatham  New York      2504.0   435000.0
# 835   4.0   3.0  East Chatham  New York      2891.0   649900.0
# 840   3.0   2.0  East Chatham  New York      2504.0   435000.0
# 842   4.0   3.0  East Chatham  New York      2891.0   649900.0
# 1047  4.0   3.0  East Chatham  New York      2508.0  1225000.0
# 1087  3.0   3.0  East Chatham  New York      1800.0   499000.0
# 1410  4.0   3.0  East Chatham  New York      2508.0  1225000.0
# 1572  3.0   3.0  East Chatham  New York      1800.0   499000.0
# ...

# %%
df13 = pd.get_dummies(df12)
df13
# Out:
#         bed  bath  house_size     price  city_Aberdeen  city_Abington  \
# 3       3.0   3.0      1800.0  419000.0              0              0
# 13      4.0   3.0      2274.0  194900.0              0              0
# 16      3.0   2.0      2504.0  435000.0              0              0
# 17      4.0   3.0      2248.0  429900.0              0              0
# 19      4.0   4.0      1980.0  649000.0              0              0
# ...     ...   ...         ...       ...            ...            ...
# 604332  5.0   4.0      3337.0  925000.0              0              0
# 604342  5.0   3.0      1998.0  379900.0              0              0
# 604348  2.0   3.0      3300.0  718000.0              0              0
# 604391  3.0   2.0      1828.0  895000.0              0              0
# 604395  3.0   4.0      1917.0  569990.0              0              0
#
#         city_Absecon  city_Acton  city_Acushnet  city_Adams  ...  \
# ...

# %%
Y = df13['price']
X = df13.drop(['price'], axis='columns')
X
# Out:
#         bed  bath  house_size  city_Aberdeen  city_Abington  city_Absecon  \
# 3       3.0   3.0      1800.0              0              0             0
# 13      4.0   3.0      2274.0              0              0             0
# 16      3.0   2.0      2504.0              0              0             0
# 17      4.0   3.0      2248.0              0              0             0
# 19      4.0   4.0      1980.0              0              0             0
# ...     ...   ...         ...            ...            ...           ...
# 604332  5.0   4.0      3337.0              0              0             0
# 604342  5.0   3.0      1998.0              0              0             0
# 604348  2.0   3.0      3300.0              0              0             0
# 604391  3.0   2.0      1828.0              0              0             0
# 604395  3.0   4.0      1917.0              0              0             0
#
#         city_Acton  city_Acushnet  city_Adams  city_Addisleigh Park  ...  \
# ...

# %%
X.drop(['state_Massachusetts', 'state_New Jersey', 'state_New York'], axis='columns')
# Out:
#         bed  bath  house_size  city_Aberdeen  city_Abington  city_Absecon  \
# 3       3.0   3.0      1800.0              0              0             0
# 13      4.0   3.0      2274.0              0              0             0
# 16      3.0   2.0      2504.0              0              0             0
# 17      4.0   3.0      2248.0              0              0             0
# 19      4.0   4.0      1980.0              0              0             0
# ...     ...   ...         ...            ...            ...           ...
# 604332  5.0   4.0      3337.0              0              0             0
# 604342  5.0   3.0      1998.0              0              0             0
# 604348  2.0   3.0      3300.0              0              0             0
# 604391  3.0   2.0      1828.0              0              0             0
# 604395  3.0   4.0      1917.0              0              0             0
#
#         city_Acton  city_Acushnet  city_Adams  city_Addisleigh Park  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.33)

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
dtr.score(X_test, y_test)
# Out:
# 0.980734760894956

# %%
X.columns
# Out:
# Index(['bed', 'bath', 'house_size', 'city_Aberdeen', 'city_Abington',
#        'city_Absecon', 'city_Acton', 'city_Acushnet', 'city_Adams',
#        'city_Addisleigh Park',
#        ...
#        'city_Worthington', 'city_Wrentham', 'city_Wrightstown', 'city_Wyckoff',
#        'city_Yarmouth', 'city_Yarmouth Port', 'city_Yonkers',
#        'state_Massachusetts', 'state_New Jersey', 'state_New York'],
#       dtype='object', length=1197)

# %%
df12.city.nunique()
# Out:
# 1191

# %%
np.where(X.columns=='city_New York')[0][0]
# Out:
# 696

# %%
import numpy as np
def predict_price(bed,bath,house_size,city):
    loc_index = np.where(X.columns==city)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = bed
    x[1] = bath
    x[2] = house_size
    if loc_index >= 0:
        x[loc_index] = 1

    return dtr.predict([x])[0]

# %%
predict_price(4.0, 3.0, 2944, 'city_East Chatham')
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# 815000.0

# %%
import pickle
from sklearn.externals import joblib
joblib.dump()
with open('banglore_home_prices_model.pickle','wb') as f:
    pickle.dump(dtr,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
